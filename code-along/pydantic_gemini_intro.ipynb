# %% [markdown]
# # Pydantic with Gemini Intro

# %% [markdown]
# ### Structure Gemini output

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List five Asian soups recipes with a yummy description.
    List the ingredients.
    """
)
print(response.text)
# Out:
# Here are five delicious Asian soup recipes, each with a yummy description and a list of ingredients:
#
# ---
#
# ### 1. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **Yummy Description:** Imagine a symphony of aromatic spices dancing in a rich, slow-simmered beef broth, poured over tender slices of beef and slippery rice noodles. This iconic Vietnamese comfort food is a fragrant hug in a bowl, often garnished with fresh herbs, bean sprouts, and a squeeze of lime to awaken every single taste bud. It's warm, soothing, and utterly addictive!
#
# **Ingredients:**
# *   **For the Broth:**
#     *   2-3 lbs beef bones (marrow, knuckle, oxtail)
#     *   1 lb beef chuck or brisket (for cooking in broth, then slicing)
#     *   1 large onion, halved and charred
#     *   4-5 inches ginger, sliced and charred
#     *   6-8 star anise
#     *   2-3 cinnamon sticks
#     *   6-8 whole cloves
#     *   2-3 black cardamom pods
#     *   1 tbsp coriander seeds
#     *   1-2 tbsp fish sauce
#     *   1-2 tbsp rock sugar (or granulated sugar)
#     *   Salt to taste
#     *   12-16 cups water
# *   **For the Soup:**
#     *   1 lb flat rice stick noodles (banh pho)
#     *   1/2 lb thinly sliced raw beef (e.g., sirloin, eye of round, or flank steak)
# *   **Fresh Toppings (essential!):**
#     *   Fresh bean sprouts
#     *   Thai basil leaves
#     *   Fresh cilantro, chopped
#     *   Lime wedges
#     *   Sliced chilies (e.g., jalapeño or bird's eye)
#     *   Hoisin sauce
#     *   Sriracha
#
# ---
#
# ### 2. Thai Tom Yum Goong (Spicy Shrimp Soup)
#
# **Yummy Description:** Prepare for a vibrant explosion of flavors! This classic Thai hot and sour soup is a zesty, aromatic marvel, brimming with plump shrimp, earthy mushrooms, and a fragrant trifecta of lemongrass, galangal, and kaffir lime leaves. Each spoonful delivers a tantalizing balance of spicy, sour, salty, and a hint of sweet, making it an exhilarating culinary adventure that will tantalize your taste buds!
#
# **Ingredients:**
# *   1 lb large shrimp, peeled and deveined (tails on)
# *   1 cup mushrooms (e.g., straw mushrooms, oyster mushrooms, or button mushrooms), halved
# *   4-5 stalks lemongrass, outer layers removed, bruised and sliced into 1-inch pieces
# *   4-5 slices galangal (fresh or frozen)
# *   6-8 kaffir lime leaves, torn
# *   2-3 bird's eye chilies, crushed or sliced (adjust to heat preference)
# *   2-3 tbsp fish sauce
# *   3-4 tbsp fresh lime juice
# *   1-2 tsp sugar (to balance flavors)
# *   1-2 tbsp roasted chili paste in oil (Nam Prik Pao, optional, for richer color/flavor)
# *   4 cups chicken or vegetable broth (or water)
# *   1/4 cup evaporated milk or coconut milk (optional, for a creamier version – Tom Yum Goong Nam Khon)
# *   Fresh cilantro, for garnish
#
# ---
#
# ### 3. Japanese Shoyu Ramen
#
# **Yummy Description:** Dive into a bowl of pure umami bliss with Japanese Shoyu Ramen! This deeply savory soup features a glistening, soy-sauce-based broth that coats perfectly springy ramen noodles. Crowned with tender slices of melt-in-your-mouth chashu pork, a jammy ajitama egg, crisp nori, and fresh scallions, it’s a symphony of textures and flavors that’s both comforting and exquisitely satisfying.
#
# **Ingredients:**
# *   **For the Broth (combine Dashi with a rich chicken or pork broth):**
#     *   6 cups water
#     *   1 piece kombu (dried kelp)
#     *   1 cup katsuobushi (bonito flakes)
#     *   6 cups chicken or pork broth (homemade from bones, or good quality store-bought)
#     *   2-3 slices ginger
#     *   2 cloves garlic
#     *   1-2 green onions (white parts)
# *   **For the Shoyu Tare (Soy Sauce Concentrate):**
#     *   1/2 cup soy sauce
#     *   1/4 cup mirin
#     *   2 tbsp sake (optional)
#     *   1 tsp sugar
# *   **For the Noodles & Toppings:**
#     *   4 servings fresh or dried ramen noodles
#     *   8-12 slices chashu (braised pork belly or shoulder)
#     *   4 ajitama (marinated soft-boiled eggs), halved
#     *   4 sheets nori (dried seaweed)
#     *   1/2 cup sliced scallions (green onions)
#     *   Menma (marinated bamboo shoots, optional)
#     *   Narutomaki (fish cake, optional)
#
# ---
#
# ### 4. Malaysian Curry Laksa (Laksa Lemak)
#
# **Yummy Description:** Indulge in the creamy, spicy, and utterly irresistible embrace of Malaysian Curry Laksa! This vibrant, coconut-rich noodle soup is a culinary masterpiece, boasting a complex broth infused with aromatic spices, chili, and a hint of sweetness. It’s generously loaded with springy noodles, succulent shrimp or chicken, tofu puffs, and fish cake, creating a textural paradise with every slurp. A squeeze of lime and a dollop of sambal on the side elevate this soulful dish to pure perfection.
#
# **Ingredients:**
# *   **For the Laksa Paste (or 1/4 cup good quality store-bought paste):**
#     *   10-12 dried red chilies, soaked and deseeded (adjust for heat)
#     *   6-8 shallots, roughly chopped
#     *   4-5 cloves garlic
#     *   2-inch piece galangal, sliced
#     *   2 stalks lemongrass, sliced (white part only)
#     *   1-inch piece fresh turmeric (or 1 tsp ground)
#     *   1 tbsp coriander seeds, toasted
#     *   1 tsp cumin seeds, toasted
#     *   3-4 candlenuts (or macadamia nuts)
#     *   1 tsp shrimp paste (belacan), toasted
# *   **For the Soup:**
#     *   2 tbsp cooking oil
#     *   4 cups chicken or shrimp broth
#     *   2 cups thick coconut milk
#     *   1 cup thin coconut milk (or water)
#     *   1 tbsp sugar
#     *   Salt to taste
# *   **For the Noodles & Toppings:**
#     *   1/2 lb thick rice vermicelli noodles, cooked
#     *   1/2 lb yellow egg noodles, cooked
#     *   1 cup cooked chicken, shredded, or 1/2 lb cooked shrimp
#     *   1 cup fried tofu puffs, halved
#     *   1/2 cup sliced fish cake
#     *   1 cup fresh bean sprouts
#     *   Fresh cilantro, chopped
#     *   Laksa leaves (Vietnamese coriander/polygonum), if available
#     *   Lime wedges
#     *   Sambal (chili paste), for serving
#
# ---
#
# ### 5. Chinese Hot and Sour Soup
#
# **Yummy Description:** Awaken your senses with the exhilarating tango of flavors in Chinese Hot and Sour Soup! This beloved classic is a marvel of culinary balance, delivering a delightful warmth from white pepper and chilies, complemented by a zesty tang from vinegar. Loaded with thinly sliced pork, crunchy bamboo shoots, earthy mushrooms, and silken tofu in a thick, savory broth, it's a comforting yet exciting soup that promises to tantalize your palate and leave you craving more.
#
# **Ingredients:**
# *   4 cups chicken or vegetable broth
# *   1/2 lb pork (loin or shoulder), thinly sliced or shredded
# *   1 cup shredded bamboo shoots
# *   1/2 cup rehydrated dried shiitake mushrooms, sliced (or fresh cremini/button mushrooms)
# *   1/4 cup rehydrated wood ear mushrooms, sliced (optional)
# *   1/2 block firm or silken tofu, cubed
# *   1/4 cup soy sauce
# *   1/4 cup rice vinegar (or Chinese black vinegar for a deeper flavor)
# *   1-2 tbsp white pepper (generous amount, adjust to taste)
# *   1-2 tbsp chili oil or chili paste (optional, for extra heat)
# *   1-2 tsp sesame oil
# *   2 tbsp cornstarch mixed with 1/4 cup water (for slurry)
# *   2 large eggs, beaten
# *   2-3 green onions, sliced, for garnish
# *   Salt and sugar, to taste
# *   A pinch of ground ginger (optional)

# %%
from pydantic import BaseModel

class Recipe(BaseModel):
    title: str
    description : str
    ingreditents : list[str]


response = client.models.generate_content(
    model="gemini-2.5-flash", contents="""
    List five Asian soups recipes with a yummy description.
    List the ingredients.
    """,
    config={"response_mime_type":"application/json", "response_schema":list[Recipe]}
)

print(response.text)
# Out:
# [
#   {
#     "title": "Classic Shoyu Ramen",
#     "description": "A deeply satisfying Japanese noodle soup featuring springy noodles nestled in a rich, umami-packed soy-based broth, topped with tender chashu pork, a perfectly jammy egg, and fresh scallions. It's pure comfort in a bowl!",
#     "ingreditents": [
#       "Ramen noodles",
#       "Pork belly (for chashu)",
#       "Chicken broth",
#       "Soy sauce",
#       "Mirin",
#       "Sake",
#       "Ginger",
#       "Garlic",
#       "Scallions",
#       "Soft-boiled eggs",
#       "Nori (seaweed sheets)",
#       "Sesame oil"
#     ]
#   },
#   {
#     "title": "Spicy Thai Tom Yum Goong",
#     "description": "Brace yourself for a vibrant explosion of flavors with this iconic Thai hot and sour shrimp soup! Zesty lime, fiery chilies, aromatic lemongrass, and galangal dance together in a fragrant broth, creating an unbelievably addictive and refreshing experience.",
#     "ingreditents": [
#       "Shrimp",
#       "Lemongrass",
#       "Galangal",
#       "Kaffir lime leaves",
#       "Fish sauce",
#       "Lime juice",
#       "Chili paste (Nam Prik Pao)",
#       "Mushrooms (straw or oyster)",
#       "Cherry tomatoes",
#       "Cilantro",
#       "Bird's eye chilies",
#       "Chicken or vegetable broth"
#     ]
#   },
#   {
#     "title": "Authentic Vietnamese Beef Pho",
#     "description": "Indulge in the aromatic magic of Vietnamese Pho, a soul-warming beef noodle soup with a crystal-clear, deeply spiced broth simmered for hours, served with tender slices of beef, slippery rice noodles, and a mountain of fresh herbs and sprouts. It's an unforgettable culinary journey!",
#     "ingreditents": [
#       "Beef bones",
#       "Beef shank or brisket",
#       "Rice noodles (Banh Pho)",
#       "Onions",
#       "Ginger",
#       "Star anise",
#       "Cinnamon sticks",
#       "Cloves",
#       "Cardamom pods",
#       "Fish sauce",
#       "Bean sprouts",
#       "Thai basil",
#       "Cilantro",
#       "Lime wedges",
#       "Jalapeno slices"
#     ]
#   },
#   {
#     "title": "Simple Japanese Miso Soup",
#     "description": "A truly comforting and healthful classic, this Japanese Miso Soup offers a gentle embrace of savory umami. Delicate cubes of tofu, tender wakame seaweed, and thinly sliced scallions float in a warm, fragrant dashi broth infused with rich miso paste. A perfect start to any meal!",
#     "ingreditents": [
#       "Dashi (kelp and bonito flakes broth)",
#       "Miso paste (white or red)",
#       "Tofu (silken or firm)",
#       "Wakame seaweed (dried)",
#       "Scallions"
#     ]
#   },
#   {
#     "title": "Classic Chinese Hot and Sour Soup",
#     "description": "Tingle your taste buds with this popular Chinese Hot and Sour Soup! A tantalizing blend of tangy vinegar, fiery white pepper, savory broth, and a delightful mix of shredded pork, tofu, mushrooms, and bamboo shoots. Thick, rich, and utterly irresistible, it's a symphony of flavors.",
#     "ingreditents": [
#       "Pork (shredded)",
#       "Tofu (firm, shredded)",
#       "Dried shiitake mushrooms",
#       "Bamboo shoots (shredded)",
#       "Wood ear mushrooms",
#       "Chicken or vegetable broth",
#       "Rice vinegar",
#       "Soy sauce",
#       "White pepper",
#       "Sesame oil",
#       "Cornstarch slurry",
#       "Eggs (beaten)",
#       "Scallions"
#     ]
#   }
# ]

# %%
#parsed go from str to list
recipes = response.parsed
type(recipes), len(recipes)
# Out:
# (list, 5)

# %%
recipes[-1].title, recipes[-1].ingreditents
# Out:
# ('Classic Chinese Hot and Sour Soup',
#  ['Pork (shredded)',
#   'Tofu (firm, shredded)',
#   'Dried shiitake mushrooms',
#   'Bamboo shoots (shredded)',
#   'Wood ear mushrooms',
#   'Chicken or vegetable broth',
#   'Rice vinegar',
#   'Soy sauce',
#   'White pepper',
#   'Sesame oil',
#   'Cornstarch slurry',
#   'Eggs (beaten)',
#   'Scallions'])
